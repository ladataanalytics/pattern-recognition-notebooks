# %% [markdown]
# # 🔮 ETS & ARIMA Forecasting
# ### Naive baselines, Holt-Winters ETS, ARIMA via AutoARIMA (statsforecast), MAE/RMSE/MAPE evaluation
#
# *fpppy Ch 7–9 · [Data Pattern Recognition for the Rest of Us](https://ladataanalytics.github.io/pattern-recognition-notebooks)*
#
# Builds directly on **Time Series Foundations** — the ACF/PACF reading skill from that notebook is what AutoARIMA below does automatically, and what you'll use to sanity-check its output.

# %% [markdown]
# ## 🎯 Concept & intuition
#
# Forecasting models exist on a spectrum of complexity. You should always benchmark a fancy model against something dumb-simple — if it can't beat the naive baseline, it isn't earning its complexity.
#
# - **Naive** — tomorrow = today. **Seasonal naive** — this month = the same month last year. Shockingly hard to beat on many series.
# - **ETS (Error-Trend-Seasonal / Holt-Winters)** — exponentially-weighted smoothing of level, trend, and seasonal components. Good default for series with a clear, stable pattern.
# - **ARIMA(p,d,q)** — models the autocorrelation structure directly, after differencing to reach stationarity. Historically the hardest part was *choosing* (p,d,q) by eye from ACF/PACF plots — that's what **AutoARIMA** automates.
#
# We'll use **[statsforecast](https://nixtlaverse.nixtla.io/statsforecast/)** (Nixtla) for `AutoARIMA` — a fast, well-maintained implementation that searches over (p,d,q)(P,D,Q) orders using AICc, the same criterion your foundations notebook flagged as the fallback when ACF/PACF plots don't give a clean read.

# %%
import os
if not os.path.exists('data/AirPassengers.csv'):
    if not os.path.exists('_repo'):
        os.system('git clone -q https://github.com/ladataanalytics/pattern-recognition-notebooks.git _repo')
    os.chdir('_repo')

# %%
# !pip install -q statsforecast

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsforecast import StatsForecast
from statsforecast.models import AutoARIMA

plt.rcParams['figure.figsize'] = (11, 4)

df = pd.read_csv('data/AirPassengers.csv')
df.columns = ['ds', 'y']
df['ds'] = pd.to_datetime(df['ds'], format='%Y-%m')

# Chronological split — NEVER shuffle a time series train/test split.
h = 12  # forecast horizon: hold out the last 12 months
train, test = df.iloc[:-h].copy(), df.iloc[-h:].copy()
print(f'Train: {train.ds.min().date()} to {train.ds.max().date()} ({len(train)} obs)')
print(f'Test:  {test.ds.min().date()} to {test.ds.max().date()} ({len(test)} obs)')
# Out:
# Train: 1949-01-01 to 1959-12-01 (132 obs)
# Test:  1960-01-01 to 1960-12-01 (12 obs)

# %% [markdown]
# ## 🧮 The math — evaluation metrics
#
# $$\text{MAE} = \frac{1}{n}\sum |y_t - \hat y_t| \qquad
# \text{RMSE} = \sqrt{\frac{1}{n}\sum (y_t - \hat y_t)^2} \qquad
# \text{MAPE} = \frac{100}{n}\sum \left|\frac{y_t - \hat y_t}{y_t}\right|\%$$
#
# MAE is robust and easy to interpret in the original units. RMSE penalizes large errors more. MAPE is scale-free, so it's the one you'd use to compare accuracy *across* series with different units — useful when you're forecasting hundreds of SKUs at once.

# %%
def eval_metrics(actual, pred, name):
    actual, pred = np.asarray(actual, dtype=float), np.asarray(pred, dtype=float)
    mae  = np.mean(np.abs(actual - pred))
    rmse = np.sqrt(np.mean((actual - pred) ** 2))
    mape = np.mean(np.abs((actual - pred) / actual)) * 100
    return {'model': name, 'MAE': mae, 'RMSE': rmse, 'MAPE%': mape}

results = []

# %% [markdown]
# ## 🐍 Baseline 1 — Naive & Seasonal Naive

# %%
naive_fc = np.repeat(train['y'].iloc[-1], h)                     # last value, repeated
seasonal_naive_fc = train['y'].iloc[-12:].values                 # same month, last year

results.append(eval_metrics(test['y'], naive_fc, 'Naive'))
results.append(eval_metrics(test['y'], seasonal_naive_fc, 'Seasonal naive'))
pd.DataFrame(results)
# Out:
#             model        MAE        RMSE      MAPE%
# 0           Naive  76.000000  102.976535  14.251338
# 1  Seasonal naive  47.833333   50.708316   9.987533

# %% [markdown]
# ## 🧮 The math — Holt-Winters ETS
#
# $$\underbrace{\ell_t = \alpha(y_t - s_{t-m}) + (1-\alpha)(\ell_{t-1}+b_{t-1})}_{\text{level}} \quad
# \underbrace{b_t = \beta(\ell_t-\ell_{t-1}) + (1-\beta)b_{t-1}}_{\text{trend}} \quad
# \underbrace{s_t = \gamma(y_t-\ell_t) + (1-\gamma)s_{t-m}}_{\text{seasonal}}$$
#
# $\alpha, \beta, \gamma \in [0,1]$ control how fast each component adapts to new data — near 1 means fast-adapting, near 0 means nearly fixed. `statsmodels` estimates all three by maximum likelihood.

# %%
ets = ExponentialSmoothing(
    train['y'], trend='add', seasonal='mul', seasonal_periods=12
).fit()
ets_fc = ets.forecast(h)

results.append(eval_metrics(test['y'], ets_fc, 'Holt-Winters ETS'))
print(f"alpha={ets.params['smoothing_level']:.3f}  beta={ets.params['smoothing_trend']:.3f}  gamma={ets.params['smoothing_seasonal']:.3f}")
pd.DataFrame(results)
# Out:
# alpha=0.376  beta=0.000  gamma=0.624
#               model        MAE        RMSE      MAPE%
# 0             Naive  76.000000  102.976535  14.251338
# 1    Seasonal naive  47.833333   50.708316   9.987533
# 2  Holt-Winters ETS  10.303143   15.810380   2.207421

# %% [markdown]
# ## 🐍 ARIMA via AutoARIMA (statsforecast)
#
# `AutoARIMA` does exactly what the **ACF/PACF Explorer** in the foundations notebook trained you to do by eye — except it searches the (p,d,q)(P,D,Q) grid automatically using a stepwise search minimizing **AICc**, the same tiebreaker your foundations notebook recommends when the plots don't give a clean signature.
#
# statsforecast expects a **long-format** dataframe with columns `unique_id`, `ds`, `y` — built for forecasting many series at once, which is why it's a common production choice.

# %%
sf_train = train.copy()
sf_train['unique_id'] = 'AirPassengers'
sf_train = sf_train[['unique_id', 'ds', 'y']]

sf = StatsForecast(models=[AutoARIMA(season_length=12)], freq='MS', n_jobs=1)
sf.fit(sf_train)

arima_fc = sf.predict(h=h)
results.append(eval_metrics(test['y'].values, arima_fc['AutoARIMA'].values, 'AutoARIMA'))

# What order did it pick? This is the (p,d,q)(P,D,Q,m) your ACF/PACF reading would be aiming for.
fitted_model = sf.fitted_[0, 0].model_
p, q, P, Q, m, d, D = fitted_model['arma']
print(f'AutoARIMA selected: ARIMA({p},{d},{q})({P},{D},{Q})[{m}]   AICc={fitted_model["aicc"]:.2f}')
pd.DataFrame(results)
# Out:
# AutoARIMA selected: ARIMA(1,1,0)(0,1,0)[12]   AICc=900.01
#               model        MAE        RMSE      MAPE%
# 0             Naive  76.000000  102.976535  14.251338
# 1    Seasonal naive  47.833333   50.708316   9.987533
# 2  Holt-Winters ETS  10.303143   15.810380   2.207421
# 3         AutoARIMA  18.515821   23.919481   4.179692

# %% [markdown]
# ## 📊 Visualization — all forecasts vs actual

# %%
fig, ax = plt.subplots(figsize=(12, 4.5))
ax.plot(df['ds'], df['y'], label='Actual', color='black', linewidth=1)
ax.plot(test['ds'], naive_fc, '--', label='Naive')
ax.plot(test['ds'], seasonal_naive_fc, '--', label='Seasonal naive')
ax.plot(test['ds'], ets_fc, '--', label='Holt-Winters ETS')
ax.plot(test['ds'], arima_fc['AutoARIMA'].values, '--', label='AutoARIMA', linewidth=2)
ax.axvline(train['ds'].iloc[-1], color='gray', linestyle=':', alpha=0.6)
ax.set_title('12-month holdout — forecasts vs actual')
ax.legend()
plt.tight_layout()
plt.show()

pd.DataFrame(results).sort_values('RMSE')
# Out:
#               model        MAE        RMSE      MAPE%
# 2  Holt-Winters ETS  10.303143   15.810380   2.207421
# 3         AutoARIMA  18.515821   23.919481   4.179692
# 1    Seasonal naive  47.833333   50.708316   9.987533
# 0             Naive  76.000000  102.976535  14.251338

# %% [markdown]
# ## 📊 Residual diagnostics
#
# A good model's residuals should look like white noise — no leftover autocorrelation for the ACF/PACF Explorer's "white noise" signature to catch. We check this with a **Ljung-Box test**: $H_0$ = residuals are white noise (no autocorrelation up to lag $k$).

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.stats.diagnostic import acorr_ljungbox

residuals = fitted_model['residuals']

fig, ax = plt.subplots(figsize=(8, 3))
plot_acf(residuals, lags=24, ax=ax, zero=False, title='ACF of AutoARIMA residuals')
plt.tight_layout()
plt.show()

lb = acorr_ljungbox(residuals, lags=[12], return_df=True)
verdict = 'white noise ✓ (model captured the structure)' if lb['lb_pvalue'].iloc[0] > 0.05 else 'still autocorrelated — model underfit'
print(lb)
print('Verdict:', verdict)
# Out:
#       lb_stat  lb_pvalue
# 12  10.307251   0.589025
# Verdict: white noise ✓ (model captured the structure)

# %% [markdown]
# ## 💼 Exercise
#
# 1. Refit `AutoARIMA` with `season_length=1` (i.e. tell it to ignore seasonality) and compare its MAE/RMSE/MAPE to the seasonal version above. How much does seasonality matter here?
# 2. Try a **6-month** horizon instead of 12 (`h=6`) — does the model ranking change?
# 3. Using the residual ACF cell as a template, plot the residual ACF for the **Holt-Winters ETS** model instead. Does it look more or less like white noise than AutoARIMA's?

# %%
# YOUR CODE HERE
# Refit AutoARIMA with season_length=1 and compare metrics to the seasonal (season_length=12) version above.

# %% [markdown]
# ## 📝 Quiz
#
# 1. What do the three parameters of ARIMA(p,d,q) each represent?
# 2. Why can you NOT randomly shuffle the train/test split for time series?
# 3. What does AICc measure, and why does AutoARIMA use it (rather than just picking the largest model) to choose between candidate orders?
# 4. If AutoARIMA's residuals show a significant ACF spike at lag 12, what does that suggest, and what would you change?
# 5. Name one scenario where the seasonal naive baseline would beat AutoARIMA, and explain why.

# %% [markdown]
# **Q1 answer:**
#
# _(replace this line with your answer)_

# %% [markdown]
# **Q2 answer:**
#
# _(replace this line with your answer)_

# %% [markdown]
# **Q3 answer:**
#
# _(replace this line with your answer)_

# %% [markdown]
# **Q4 answer:**
#
# _(replace this line with your answer)_

# %% [markdown]
# **Q5 answer:**
#
# _(replace this line with your answer)_

# %%
# 🤖 AI GRADING — run this cell, copy the printed prompt, paste into the ✨ Gemini button (top-right of Colab)
questions = ['What do the three parameters of ARIMA(p,d,q) each represent?', 'Why can you NOT randomly shuffle the train/test split for time series?', 'What does AICc measure, and why does AutoARIMA use it (rather than just picking the largest model) to choose between candidate orders?', "If AutoARIMA's residuals show a significant ACF spike at lag 12, what does that suggest, and what would you change?", 'Name one scenario where the seasonal naive baseline would beat AutoARIMA, and explain why.']
your_answers = [
    "YOUR ANSWER HERE",  # Q1,
    "YOUR ANSWER HERE",  # Q2,
    "YOUR ANSWER HERE",  # Q3,
    "YOUR ANSWER HERE",  # Q4,
    "YOUR ANSWER HERE",  # Q5
]

prompt = "Grade these time-series quiz answers. For each question, say CORRECT / PARTIAL / INCORRECT with one sentence of feedback, then give an overall score and what to review.\n\n"
for i, (q, a) in enumerate(zip(questions, your_answers), 1):
    prompt += f"Q{i}: {q}\nMy answer: {a}\n\n"

print(prompt)
# Out:
# Grade these time-series quiz answers. For each question, say CORRECT / PARTIAL / INCORRECT with one sentence of feedback, then give an overall score and what to review.
#
# Q1: What do the three parameters of ARIMA(p,d,q) each represent?
# My answer: YOUR ANSWER HERE
#
# Q2: Why can you NOT randomly shuffle the train/test split for time series?
# My answer: YOUR ANSWER HERE
#
# Q3: What does AICc measure, and why does AutoARIMA use it (rather than just picking the largest model) to choose between candidate orders?
# My answer: YOUR ANSWER HERE
#
# Q4: If AutoARIMA's residuals show a significant ACF spike at lag 12, what does that suggest, and what would you change?
# My answer: YOUR ANSWER HERE
#
# Q5: Name one scenario where the seasonal naive baseline would beat AutoARIMA, and explain why.
# My answer: YOUR ANSWER HERE

# %% [markdown]
# ## 📚 Further reading
#
# - [fpppy — Forecasting: Principles & Practice (Pythonic)](https://otexts.com/fpppy/)
# - [statsforecast documentation (Nixtla)](https://nixtlaverse.nixtla.io/statsforecast/)
# - [statsmodels time series docs](https://www.statsmodels.org/stable/tsa.html)
# - Back to the [course navigator](https://ladataanalytics.github.io/pattern-recognition-notebooks)
